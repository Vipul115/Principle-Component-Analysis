# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition
from sklearn import datasets

# %%
ds = pd.read_csv("dataset\S01R02.csv")
ds1 = ds[ds["Annotation [0/1/2]"] == 1]
ds2 = ds[ds["Annotation [0/1/2]"] == 2]
ds.head()
# Out:
#    Time of Sample (ms)  \
# 0                   15
# 1                   31
# 2                   46
# 3                   62
# 4                   78
#
#    Ankle (shank) acceleration - horizontal forward acceleration [mg]  \
# 0                                                 40
# 1                                                 70
# 2                                                 60
# 3                                                 60
# 4                                                 50
#
#    Ankle (shank) acceleration - vertical [mg]  \
# 0                                          29
# 1                                          49
# 2                                          29
# 3                                          29
# 4                                          19
#
#    Ankle (shank) acceleration - horizontal lateral [mg]  \
# 0                                               -960
# 1                                               -960
# ...

# %%
X1 = ds1[ds1.columns[1:-1]]
y1 = ds1["Annotation [0/1/2]"]

X2 = ds2[ds2.columns[1:-1]]
y2 = ds2["Annotation [0/1/2]"]

fig = plt.figure()
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

def scatter_plot(X,y, param_color,s1):
    
    pca = decomposition.PCA(n_components=3)
    pca.fit(X)
    X = pca.transform(X)

    ax.scatter(X[:, 0], X[:, 1], X[:, 2],  c=param_color ,s=s1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
scatter_plot(X1, y1, 'blue',0.1)
scatter_plot(X2, y2, 'red',5)
